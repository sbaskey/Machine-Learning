# %%
import pandas as pd

# %%
data=pd.read_excel("Advertising.xlsx")
data.head()
# Out:
#       TV  Radio  Newspaper      Area Prod_type  Sales
# 0  230.1   37.8       69.2  suburban     Basic   38.0
# 1   44.5   39.3       45.1     rural    Higher   10.4
# 2   17.2   45.9       69.3     rural    Medium    9.3
# 3  151.5   41.3       58.5  suburban    Medium   18.5
# 4  180.8   10.8       58.4  suburban    Higher   12.9

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (200, 6)

# %%
data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  198.000000  198.000000  200.000000
# mean   149.635500   23.462626   30.621717   15.591500
# std     97.035865   14.787748   21.878334    8.332438
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000   10.225000   12.650000   10.375000
# 50%    149.750000   23.450000   26.050000   13.350000
# 75%    218.825000   36.575000   45.100000   18.925000
# max    800.000000   49.600000  114.000000   52.000000

# %%
data.groupby('Area').size()
# Out:
# Area
# rural       95
# suburban    83
# urban       22
# dtype: int64

# %%
data.groupby('Prod_type').size()
# Out:
# Prod_type
# Basic     70
# Higher    70
# Medium    60
# dtype: int64

# %%
data.Prod_type.value_counts()
# Out:
# Basic     70
# Higher    70
# Medium    60
# Name: Prod_type, dtype: int64

# %%
data.Prod_type.value_counts(normalize=True)
# Out:
# Basic     0.35
# Higher    0.35
# Medium    0.30
# Name: Prod_type, dtype: float64

# %%
data.isnull()
# Out:
#         TV  Radio  Newspaper   Area  Prod_type  Sales
# 0    False  False      False  False      False  False
# 1    False  False      False  False      False  False
# 2    False  False      False  False      False  False
# 3    False  False      False  False      False  False
# 4    False  False      False  False      False  False
# 5    False  False      False  False      False  False
# 6    False  False       True  False      False  False
# 7    False  False      False  False      False  False
# 8    False   True      False  False      False  False
# 9    False  False      False  False      False  False
# 10   False  False       True  False      False  False
# 11   False  False      False  False      False  False
# 12   False  False      False  False      False  False
# 13   False  False      False  False      False  False
# 14   False  False      False  False      False  False
# 15   False  False      False  False      False  False
# ...

# %%
data.isnull().sum()
# Out:
# TV           0
# Radio        2
# Newspaper    2
# Area         0
# Prod_type    0
# Sales        0
# dtype: int64

# %%
data[data.Radio.isnull()]
# Out:
#        TV  Radio  Newspaper      Area Prod_type  Sales
# 8     8.6    NaN        1.0     rural    Medium    4.8
# 21  237.4    NaN       23.5  suburban    Higher   12.5

# %%
data[data.Newspaper.isnull()]
# Out:
#       TV  Radio  Newspaper   Area Prod_type  Sales
# 6   57.5   32.8        NaN  urban     Basic   11.8
# 10  66.1    5.8        NaN  rural    Higher    8.6

# %%
data[data.isnull().any(axis=1)]
# Out:
#        TV  Radio  Newspaper      Area Prod_type  Sales
# 6    57.5   32.8        NaN     urban     Basic   11.8
# 8     8.6    NaN        1.0     rural    Medium    4.8
# 10   66.1    5.8        NaN     rural    Higher    8.6
# 21  237.4    NaN       23.5  suburban    Higher   12.5

# %%
data.Newspaper.fillna(data.Newspaper.mean(),inplace=True)

# %%
data.Radio.fillna(data.Radio.mean(),inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.boxplot(data.TV,color='green',orient="v");

# %%
data.corr(method='pearson')
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.073819   0.078454  0.641726
# Radio      0.073819  1.000000   0.344816  0.263967
# Newspaper  0.078454  0.344816   1.000000  0.196887
# Sales      0.641726  0.263967   0.196887  1.000000
